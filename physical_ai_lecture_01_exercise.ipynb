# %% [markdown]
# <a href="https://colab.research.google.com/github/SAO-P/Basic-Physical-AI-2026-Spring/blob/main/physical_ai_lecture_01_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Physical AI 基礎編 知能ロボティクス講座 2026 Spring 第1回 演習資料
# ## LeRobot × SmolVLA × LIBERO で学ぶ VLA 推論までの流れ
#
# このノートブックでは、Hugging Face の軽量な VLA モデル **SmolVLA** の LIBERO 用チェックポイント `HuggingFaceVLA/smolvla_libero` を使い、ロボットのマニピュレーション用ベンチマーク **LIBERO** 上で
# **推論 → 評価 → 可視化** までを体験します。

# %% [markdown]
# ## GPU の確認
#
# まず Colab に **T4 GPU** が割り当てられているか確認します。
# `nvidia-smi` の出力に `Tesla T4` と `15360MiB`（約 16GB）程度の VRAM が表示されれば OK です。

# %%
# !nvidia-smi
# Out:
# Sat Jun 27 16:42:18 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8             13W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## 依存関係のインストール
#
# LeRobot を **`smolvla`（SmolVLA 用）** と **`libero`（LIBERO 環境用）** の extra 付きでインストールします。
#
# (セッションリスタートが必要になります)

# %%
# !apt-get update
# !apt-get install -y \
    libegl1 libegl1-mesa-dev libgles2-mesa-dev \
    libglfw3 libosmesa6-dev libgl1-mesa-glx

# !pip install "lerobot[smolvla,libero]==0.5.1"
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libegl1 is already the newest version (1.4.0-1).
# libglfw3 is already the newest version (3.3.6-1).
# libegl1-mesa-dev is already the newest version (23.2.1-1ubuntu3.1~22.04.4).
# libgles2-mesa-dev is already the newest version (23.2.1-1ubuntu3.1~22.04.4).
# libosmesa6-dev is already the newest version (23.2.1-1ubuntu3.1~22.04.4).
# libgl1-mesa-glx is already the newest version (23.0.4-0ubuntu1~22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 100 not upgraded.
# Requirement already satisfied: lerobot==0.5.1 in /usr/local/lib/python3.12/dist-packages (from lerobot[libero,smolvla]==0.5.1) (0.5.1)
# Requirement already satisfied: datasets<5.0.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (4.0.0)
# Requirement already satisfied: diffusers<0.36.0,>=0.27.2 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.35.2)
# Requirement already satisfied: huggingface-hub<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.19.0)
# Requirement already satisfied: accelerate<2.0.0,>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.14.0)
# Requirement already satisfied: numpy<2.3.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (2.0.2)
# Requirement already satisfied: setuptools<81.0.0,>=71.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (75.2.0)
# Requirement already satisfied: cmake<4.2.0,>=3.29.0.1 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (3.31.10)
# Requirement already satisfied: packaging<26.0,>=24.2 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (25.0)
# Requirement already satisfied: torch<2.11.0,>=2.7 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (2.10.0)
# Requirement already satisfied: torchcodec<0.11.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.10.0)
# Requirement already satisfied: torchvision<0.26.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.25.0)
# Requirement already satisfied: einops<0.9.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.8.2)
# Requirement already satisfied: opencv-python-headless<4.14.0,>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (4.13.0.92)
# Requirement already satisfied: av<16.0.0,>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (15.1.0)
# Requirement already satisfied: jsonlines<5.0.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (4.0.0)
# Requirement already satisfied: pynput<1.9.0,>=1.7.8 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.8.2)
# Requirement already satisfied: pyserial<4.0,>=3.5 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (3.5)
# Requirement already satisfied: wandb<0.25.0,>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.24.2)
# Requirement already satisfied: draccus==0.10.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.10.0)
# Requirement already satisfied: gymnasium<2.0.0,>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.3.0)
# Requirement already satisfied: rerun-sdk<0.27.0,>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.26.2)
# Requirement already satisfied: deepdiff<9.0.0,>=7.0.1 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (8.6.2)
# Requirement already satisfied: imageio<3.0.0,>=2.34.0 in /usr/local/lib/python3.12/dist-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (2.37.3)
# Requirement already satisfied: termcolor<4.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (3.3.0)
# Requirement already satisfied: num2words<0.6.0,>=0.5.14 in /usr/local/lib/python3.12/dist-packages (from lerobot[libero,smolvla]==0.5.1) (0.5.14)
# Requirement already satisfied: safetensors<1.0.0,>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from lerobot[libero,smolvla]==0.5.1) (0.8.0)
# Requirement already satisfied: hf-libero<0.2.0,>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from lerobot[libero,smolvla]==0.5.1) (0.1.4)
# Requirement already satisfied: mergedeep~=1.3 in /usr/local/lib/python3.12/dist-packages (from draccus==0.10.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.3.4)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.12/dist-packages (from draccus==0.10.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (6.0.3)
# Requirement already satisfied: pyyaml-include~=1.4 in /usr/local/lib/python3.12/dist-packages (from draccus==0.10.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.12/dist-packages (from draccus==0.10.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /usr/local/lib/python3.12/dist-packages (from draccus==0.10.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.9.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (5.9.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (3.29.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (2025.3.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from deepdiff<9.0.0,>=7.0.1->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (5.5.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (8.7.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (2025.11.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (11.3.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.0.6)
# Requirement already satisfied: hf-egl-probe>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (1.0.2)
# Requirement already satisfied: hydra-core<1.4,>=1.2 in /usr/local/lib/python3.12/dist-packages (from hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (1.3.3)
# Requirement already satisfied: robomimic==0.2.0 in /usr/local/lib/python3.12/dist-packages (from hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (0.2.0)
# Requirement already satisfied: robosuite==1.4.0 in /usr/local/lib/python3.12/dist-packages (from hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (1.4.0)
# Requirement already satisfied: bddl==1.0.1 in /usr/local/lib/python3.12/dist-packages (from hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (1.0.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (5.3.0)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (1.13)
# Requirement already satisfied: thop in /usr/local/lib/python3.12/dist-packages (from hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (0.1.1.post2209072238)
# Requirement already satisfied: matplotlib>=3.5.3 in /usr/local/lib/python3.12/dist-packages (from hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (3.10.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (4.13.0.92)
# Requirement already satisfied: mujoco<3.9.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (3.8.1)
# Requirement already satisfied: future>=0.18.2 in /usr/local/lib/python3.12/dist-packages (from hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (1.0.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from bddl==1.0.1->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (8.4.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from bddl==1.0.1->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (3.6.1)
# Requirement already satisfied: jupytext in /usr/local/lib/python3.12/dist-packages (from bddl==1.0.1->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (1.19.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from robomimic==0.2.0->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (3.16.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from robomimic==0.2.0->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (2.20.0)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.12/dist-packages (from robomimic==0.2.0->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (2.6.5)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.12/dist-packages (from robomimic==0.2.0->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (0.6.0)
# Requirement already satisfied: egl-probe>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from robomimic==0.2.0->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (1.0.2)
# Requirement already satisfied: numba>=0.49.1 in /usr/local/lib/python3.12/dist-packages (from robosuite==1.4.0->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (0.60.0)
# Requirement already satisfied: scipy>=1.2.3 in /usr/local/lib/python3.12/dist-packages (from robosuite==1.4.0->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (1.16.3)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (8.4.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.28.1)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.25.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (26.1.0)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from num2words<0.6.0,>=0.5.14->lerobot[libero,smolvla]==0.5.1) (0.6.2)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from pynput<1.9.0,>=1.7.8->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.17.0)
# Requirement already satisfied: evdev>=1.3 in /usr/local/lib/python3.12/dist-packages (from pynput<1.9.0,>=1.7.8->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.9.3)
# Requirement already satisfied: python-xlib>=0.17 in /usr/local/lib/python3.12/dist-packages (from pynput<1.9.0,>=1.7.8->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.33)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.5.5)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb<0.25.0,>=0.24.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (3.1.50)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb<0.25.0,>=0.24.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (4.10.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb<0.25.0,>=0.24.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (5.29.6)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb<0.25.0,>=0.24.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (2.12.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb<0.25.0,>=0.24.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (2.62.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (0.22.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (3.14.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb<0.25.0,>=0.24.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (4.0.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.16.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.12/dist-packages (from hydra-core<1.4,>=1.2->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (2.3.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core<1.4,>=1.2->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (4.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.3->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.3->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.3->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.3->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.3->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.3->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (2.9.0.post0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mujoco<3.9.0,>=3.0.0->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.12/dist-packages (from mujoco<3.9.0,>=3.0.0->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (1.14.0)
# Requirement already satisfied: glfw in /usr/local/lib/python3.12/dist-packages (from mujoco<3.9.0,>=3.0.0->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (2.10.0)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco<3.9.0,>=3.0.0->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (3.1.10)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb<0.25.0,>=0.24.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb<0.25.0,>=0.24.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb<0.25.0,>=0.24.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.0.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers<0.36.0,>=0.27.2->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<2.11.0,>=2.7->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (3.0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (2026.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<5.0.0,>=4.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (1.24.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb<0.25.0,>=0.24.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (5.0.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.49.1->robosuite==1.4.0->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (0.43.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (2.20.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.12/dist-packages (from jupytext->bddl==1.0.1->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (0.6.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from jupytext->bddl==1.0.1->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (5.10.4)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->bddl==1.0.1->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->bddl==1.0.1->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (1.6.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->robomimic==0.2.0->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (1.81.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->robomimic==0.2.0->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->robomimic==0.2.0->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->robomimic==0.2.0->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (3.1.8)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.1->lerobot[libero,smolvla]==0.5.1) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->bddl==1.0.1->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->bddl==1.0.1->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->bddl==1.0.1->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->bddl==1.0.1->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (5.7.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->bddl==1.0.1->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->bddl==1.0.1->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->bddl==1.0.1->hf-libero<0.2.0,>=0.1.3->lerobot[libero,smolvla]==0.5.1) (2026.5.1)

# %% [markdown]
# ## SmolVLA とは
#
# **SmolVLA** は Hugging Face が 2025 年に公開した軽量な **Vision-Language-Action (VLA)** モデルです。「**1 枚の GPU で学習でき、コンシューマー GPU や CPU でも動く**」ことを目標に設計されています。
#
# ### 学習データ
# - **LeRobot コミュニティが公開した 487 個の実機データセット**で事前学習
# - 大企業の非公開・巨大データではなく、**コミュニティの公開データ中心**で作られている点が特徴（同種モデルの学習データより 1 桁以上小さい）
#
# ### 性能（LIBERO ベンチマーク, 論文報告値）
# | モデル | パラメータ数 | 平均成功率 |
# | --- | --- | --- |
# | Octo | 0.09B | 75.1% |
# | OpenVLA | 7B | 76.5% |
# | π0 | 3.3B | 86.0% |
# | **SmolVLA** | **0.45B** | **87.3%** |
#
# 本ノートブックで使う `HuggingFaceVLA/smolvla_libero` は、この SmolVLA を **LIBERO 向けに学習したチェックポイント**です。
#
# 参考:
# - 論文 https://arxiv.org/abs/2506.01844
# - 解説ブログ https://huggingface.co/blog/smolvla

# %% [markdown]
# ## LIBERO とは
#
# **LIBERO** はロボットポリシーの性能評価によく用いられる**マニピュレーションのためのベンチマーク**です（Liu et al., NeurIPS 2023）。
# シミュレータの中でのマニピュレーション（物を掴む・置く・開ける等）タスクを定義しています。
#
# ### 構成
# - 物理シミュレータ **MuJoCo** 上の **Franka Emika Panda** アーム
# - **5 つのタスクスイート（合計 130 タスク）**。各タスクには人間のデモ（テレオペ）が付属
#
# | スイート | タスク数 | 何を変えて評価するか |
# | --- | --- | --- |
# | `libero_spatial` | 10 | 物の配置（空間関係）の違い |
# | `libero_object` | 10 | 対象物体の違い |
# | `libero_goal` | 10 | ゴールの違い |
# | `libero_10` (LIBERO-Long) | 10 | 長時間・複合タスク |
# | `libero_90` | 90 | 多様な短タスク |
#
# ### 入出力
# - **観測 (observation)**
#   - `observation.state`: 8 次元の proprio（手先の位置・姿勢 6 + グリッパ（2指として扱う） 2）
#   - `observation.images.image`: メインカメラ（俯瞰）
#   - `observation.images.image2`: 手首カメラ
#   - `task`: 自然言語の指示文（例: "pick up the black bowl and put it on the plate"）
# - **アクション (action)**: 7 次元（手先の位置・姿勢の変位 6 + グリッパ開閉 1）
#
# ### 評価指標
# - 各タスクを複数エピソードずつ rollout し、**タスク成功率 (success rate)** を測ります。
# - 「成功」はタスクごとの達成条件（対象物が目標位置・状態になったか）で自動判定されます。
#
# 公式ドキュメント:
# - https://huggingface.co/docs/lerobot/libero
# - https://libero-project.github.io/main

# %% [markdown]
# ## LeRobot とは
#
# **LeRobot** は Hugging Face が開発する、**実機ロボット学習のためのオープンソース・フレームワーク**です。モデル等はすべて PyTorch で記述されています。
# **データ・モデル・学習・評価・実機制御**を一気通貫で扱うことができ、現在様々なプロジェクトで LeRobot 形式のデータセットが用いられています。
#
# ### 主な構成要素
# - **`LeRobotDataset`**: ロボットのエピソード（画像・proprio・アクション・言語指示）を統一フォーマットで扱うデータセット。
#   HF Hub から共有・ダウンロードできる（本ノートブックで用いる `HuggingFaceVLA/libero` もこちら）
# - **ロボットポリシー**: ACT, Diffusion Policy, π0, **SmolVLA** など各種ロボットポリシーの実装が含まれている
# - **環境**: LIBERO, PushT などシミュレーション環境のラッパ
#
# 公式: https://github.com/huggingface/lerobot ／ ドキュメント: https://huggingface.co/docs/lerobot

# %% [markdown]
# ## モデルのロード
#
# チェックポイント **`HuggingFaceVLA/smolvla_libero`** を `SmolVLAPolicy.from_pretrained` でロードします（`transformers` ライブラリなどとインターフェースは類似している）
#
# あわせて **前処理（preprocessor）／後処理（postprocessor）** パイプラインを `make_pre_post_processors` で構築します。
# これらは推論時に必須で、次の役割を持ちます。
#
# - **preprocessor**: 観測辞書のキー変換 → バッチ次元の付与 → 言語指示のトークナイズ → デバイス転送 → **正規化**
# - **postprocessor**: モデル出力アクションの **逆正規化** → CPU への転送
#
# 正規化統計はチェックポイント内に保存されているため、`make_pre_post_processors` の **第 2 引数に
# チェックポイント ID を渡す**ことで、学習時と同じ統計が読み込まれます（3 節で触れた「学習時と推論時で処理を一致させる」要）。

# %%
import os
import torch
from lerobot.policies.smolvla.modeling_smolvla import SmolVLAPolicy
from lerobot.policies.factory import make_pre_post_processors

os.environ["HF_XET_HIGH_PERFORMANCE"] = "1"

MODEL_ID = "HuggingFaceVLA/smolvla_libero"
device = "cuda"

# チェックポイントをロード（初回は数百 MB のダウンロードが走る）
model = SmolVLAPolicy.from_pretrained(MODEL_ID)
model = model.to(device)
model.eval()

# 前処理・後処理パイプライン（正規化統計はチェックポイントから読み込まれる）
preprocess, postprocess = make_pre_post_processors(
    model.config,
    MODEL_ID,
    preprocessor_overrides={"device_processor": {"device": device}},
)

torch.cuda.synchronize()
# !nvidia-smi
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:124: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/2.11k [00:00<?, ?B/s]
# Loading  HuggingFaceTB/SmolVLM2-500M-Instruct weights ...
# config.json:   0%|          | 0.00/3.77k [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/2.03G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/489 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/136 [00:00<?, ?B/s]
# processor_config.json:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/430 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/599 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/28.6k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/801k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/466k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/4.74k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/868 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.55M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# policy_preprocessor.json:   0%|          | 0.00/1.71k [00:00<?, ?B/s]
# policy_preprocessor_step_5_normalizer_pr(…):   0%|          | 0.00/416 [00:00<?, ?B/s]
# policy_postprocessor.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# Sat Jun 27 16:43:48 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0             26W /   70W |    1305MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A           10666      C   /usr/bin/python3                       1302MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## 推論デモ
#
# LIBERO データセット **`HuggingFaceVLA/libero`** から **1 エピソードだけ**取り出し、その先頭フレームをモデルに入力して **アクションチャンク**を出力させます。

# %%
from lerobot.datasets.lerobot_dataset import LeRobotDataset

# 1 エピソードだけロード
dataset = LeRobotDataset("HuggingFaceVLA/libero", episodes=[0])

# エピソード 0 の先頭フレーム index を取得
ep = 0
from_idx = dataset.meta.episodes["dataset_from_index"][ep]
frame = dataset[from_idx]

observation = {
    "observation.state": frame["observation.state"],
    "observation.images.image": frame["observation.images.image"],
    "observation.images.image2": frame["observation.images.image2"],
    "task": frame["task"],
}

print("=== 入力（観測）の shape ===")
print("state       :", tuple(observation["observation.state"].shape))
print("image       :", tuple(observation["observation.images.image"].shape), "(C, H, W)")
print("image2      :", tuple(observation["observation.images.image2"].shape), "(C, H, W)")
print("task (指示文):", repr(observation["task"]))
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# === 入力（観測）の shape ===
# state       : (8,)
# image       : (3, 256, 256) (C, H, W)
# image2      : (3, 256, 256) (C, H, W)
# task (指示文): 'put the white mug on the left plate and put the yellow and white mug on the right plate'

# %% [markdown]
# 入力画像（メインカメラと手首カメラ）を表示して、モデルが「何を見ているか」を確認します。

# %%
import matplotlib.pyplot as plt

# データセットの画像は (C, H, W) なので表示用に (H, W, C) へ permute
img_main = observation["observation.images.image"].permute(1, 2, 0).cpu().numpy()
img_wrist = observation["observation.images.image2"].permute(1, 2, 0).cpu().numpy()

fig, axes = plt.subplots(1, 2, figsize=(8, 4))
axes[0].imshow(img_main); axes[0].set_title("agentview (main)"); axes[0].axis("off")
axes[1].imshow(img_wrist); axes[1].set_title("eye-in-hand (wrist)"); axes[1].axis("off")
plt.suptitle(observation["task"])
plt.tight_layout()
plt.show()

# %% [markdown]
# 前処理 → 推論 → 後処理の流れを実行します。`predict_action_chunk` で **アクションチャンク全体**を、
# `select_action` で **1 ステップ分のアクション**を取得して、それぞれの shape を確認します。

# %%
model.reset()  # 各エピソードの開始時にアクションキューをクリア
processed = preprocess(observation)                  # 前処理（バッチ次元付与・トークナイズ・正規化など）
action_chunk = model.predict_action_chunk(processed) # (B, n_action_steps, action_dim)
print("=== 出力（アクションチャンク） ===")
print("action_chunk:", tuple(action_chunk.shape), "= (バッチ, ステップ数, アクション次元)")
print("アクション値の例:", [round(x, 3) for x in action_chunk[0][0].tolist()])
print("postprocess後:", [round(x, 3) for x in postprocess(action_chunk)[0][0].tolist()])
# Out:
# === 出力（アクションチャンク） ===
# action_chunk: (1, 50, 7) = (バッチ, ステップ数, アクション次元)
# アクション値の例: [-0.151, 0.766, 0.045, 0.06, -0.208, -0.699, -0.968]
# postprocess後: [0.012, 0.377, -0.07, 0.003, -0.008, -0.06, -1.017]

# %% [markdown]
# - `action_chunk` の `(B, n_action_steps, 7)` は、「1 回の推論で `n_action_steps` ステップ先までの
#   アクションをまとめて予測している」ことを表します。これは VLA の **action chunking** と呼ばれます。
# - 実際の制御では、この chunk を内部キューに溜めて `select_action` が 1 ステップずつ取り出し、キューが空になったら再推論します。

# %% [markdown]
# ## ベンチマーク評価
#
# LeRobot では、本来は `lerobot-eval` コマンドを利用することで、LIBERO シミュレータ上に実際に rollout して **タスク成功率**を測ることができます。
# ただ、今回は `lerobot-eval` を用いると中身で何をやっているかわからないため、評価スクリプトを書いて内容を理解します。

# %%
EVAL_OUT = "./eval_out"

# 以下をコメントアウトすることで lerobot-eval を実行させることも可能
# cmd = (
#     "lerobot-eval"
#     f" --policy.path={MODEL_ID}"
#     " --policy.device=cuda"
#     " --policy.n_action_steps=10"
#     " --env.type=libero"
#     " --env.task=libero_spatial"
#     ' --env.task_ids="[0]"'
#     " --eval.n_episodes=3"
#     " --eval.batch_size=1"
#     " --env.max_parallel_tasks=1"
#     f" --output_dir={EVAL_OUT}"
# )
# print(cmd, "\n")
# !{cmd}

# %%
import time
import numpy as np
import torch
from libero.libero import benchmark
from lerobot.envs.libero import LiberoEnv
import imageio

# ===== 評価設定 =====
SUITE_NAME = "libero_spatial"   # 評価するスイート
TASK_ID = 0                     # スイート内のタスク番号
N_EPISODES = 3                  # 評価エピソード数

# action chunk
model.config.n_action_steps = 10

# ===== 環境を作る =====
suite = benchmark.get_benchmark_dict()[SUITE_NAME]()
env = LiberoEnv(
    task_suite=suite,
    task_id=TASK_ID,
    task_suite_name=SUITE_NAME,
    obs_type="pixels_agent_pos",
    control_mode="relative",
    observation_width=256,
    observation_height=256,
    init_states=True,
    n_envs=1,
)
max_steps = env._max_episode_steps
print(f"タスク指示: {env.task_description}")
print(f"1 エピソードの最大ステップ: {max_steps}\n")


def quat2axisangle(quat):  # quat: torch (4,) 順序は (x, y, z, w)
    w = quat[3].clamp(-1.0, 1.0)
    den = torch.sqrt(torch.clamp(1.0 - w * w, min=0.0))
    if den < 1e-10:
        return torch.zeros(3, dtype=torch.float32)
    return (quat[:3] / den * (2.0 * torch.acos(w))).float()

def to_chw(img_hwc):
    img = np.ascontiguousarray(img_hwc[::-1, ::-1])
    return torch.from_numpy(img).permute(2, 0, 1).float() / 255.0

def build_observation(obs):
    rs = obs["robot_state"]
    eef_pos = torch.as_tensor(rs["eef"]["pos"], dtype=torch.float32)       # (3,)
    eef_quat = torch.as_tensor(rs["eef"]["quat"], dtype=torch.float32)     # (4,) (x,y,z,w)
    gripper = torch.as_tensor(rs["gripper"]["qpos"], dtype=torch.float32)  # (2,)
    state = torch.cat([eef_pos, quat2axisangle(eef_quat), gripper])        # (8,)
    return {
        "observation.state": state,
        "observation.images.image": to_chw(obs["pixels"]["image"]),
        "observation.images.image2": to_chw(obs["pixels"]["image2"]),
        "task": env.task_description,
    }


results = []         # 各エピソードの成功 / 失敗
rollout_frames = []  # 動画用フレーム
t0 = time.time()

for ep in range(N_EPISODES):
    env.init_state_id = ep   # 初期状態を固定（lerobot と同じく 0,1,2,... を使う）
    obs, info = env.reset()
    model.reset()            # アクションチャンクのキューをクリア
    success = False

    for t in range(max_steps):
        print(f"Episode {ep}: step {t + 1}")

        rollout_frames.append(np.ascontiguousarray(obs["pixels"]["image"][::-1, ::-1]))

        # 前処理 → 1 ステップ分のアクションを取得 → 後処理（逆正規化）
        processed = preprocess(build_observation(obs))
        with torch.inference_mode():
            action = model.select_action(processed)
        action = postprocess(action).squeeze(0).cpu().numpy()

        obs, reward, terminated, truncated, info = env.step(action)
        success = success or bool(info.get("is_success", False))
        if terminated:
            break

    results.append(success)
    print(f"  Episode {ep}: {'✅ 成功' if success else '❌ 失敗'}  ({t + 1} steps)")

    # Save the video
    VIDEO_PATH = f"rollout_ep{ep}.mp4"
    imageio.mimsave(VIDEO_PATH, rollout_frames, fps=30)
    rollout_frames = []

env.close()

success_rate = 100.0 * sum(results) / len(results)
print("\n=== 評価結果 ===")
print(f"成功率: {success_rate:.1f}%  ({sum(results)}/{len(results)} episodes)")
print(f"所要時間: {time.time() - t0:.1f} 秒")
# Out:
# Do you want to specify a custom path for the dataset folder? (Y/N): N
# Initializing the default config file...
# The following information is stored in the config file: /root/.libero/config.yaml
# benchmark_root: /usr/local/lib/python3.12/dist-packages/libero/libero
# bddl_files: /usr/local/lib/python3.12/dist-packages/libero/libero/./bddl_files
# init_states: /usr/local/lib/python3.12/dist-packages/libero/libero/./init_files
# datasets: /usr/local/lib/python3.12/dist-packages/libero/libero/../datasets
# assets: /usr/local/lib/python3.12/dist-packages/libero/libero/./assets
# [robosuite WARNING] No private macro file found! (__init__.py:7)
# Episode 1: step 179
# Episode 1: step 180
# Episode 1: step 181
# Episode 1: step 182
# Episode 1: step 183
# Episode 1: step 184
# Episode 1: step 185
# Episode 1: step 186
# Episode 1: step 187
# Episode 1: step 188
# Episode 1: step 189
# Episode 1: step 190
# Episode 1: step 191
# Episode 1: step 192
# Episode 1: step 193
# Episode 1: step 194
# Episode 1: step 195
# Episode 1: step 196
# Episode 1: step 197
# Episode 1: step 198
# Episode 1: step 199
# Episode 1: step 200
# Episode 1: step 201
# Episode 1: step 202
# Episode 1: step 203
# Episode 1: step 204
# Episode 1: step 205
# Episode 1: step 206
# Episode 1: step 207
# Episode 1: step 208
# Episode 1: step 209
# Episode 1: step 210
# Episode 1: step 211
# Episode 1: step 212
# Episode 1: step 213
# Episode 1: step 214
# Episode 1: step 215
# Episode 1: step 216
# Episode 1: step 217
# Episode 1: step 218
# Episode 1: step 219
# Episode 1: step 220
# Episode 1: step 221
# Episode 1: step 222
# Episode 1: step 223
# Episode 1: step 224
# Episode 1: step 225
# Episode 1: step 226
# Episode 1: step 227
# Episode 1: step 228
# Episode 1: step 229
# Episode 1: step 230
# Episode 1: step 231
# Episode 1: step 232
# Episode 1: step 233
# Episode 1: step 234
# Episode 1: step 235
# Episode 1: step 236
# Episode 1: step 237
# Episode 1: step 238
# Episode 1: step 239
# Episode 1: step 240
# Episode 1: step 241
# Episode 1: step 242
# Episode 1: step 243
# Episode 1: step 244
# Episode 1: step 245
# Episode 1: step 246
# Episode 1: step 247
# Episode 1: step 248
# Episode 1: step 249
# Episode 1: step 250
# Episode 1: step 251
# Episode 1: step 252
# Episode 1: step 253
# Episode 1: step 254
# Episode 1: step 255
# Episode 1: step 256
# Episode 1: step 257
# Episode 1: step 258
# Episode 1: step 259
# Episode 1: step 260
# Episode 1: step 261
# Episode 1: step 262
# Episode 1: step 263
# Episode 1: step 264
# Episode 1: step 265
# Episode 1: step 266
# Episode 1: step 267
# Episode 1: step 268
# Episode 1: step 269
# Episode 1: step 270
# Episode 1: step 271
# Episode 1: step 272
# Episode 1: step 273
# Episode 1: step 274
# Episode 1: step 275
# Episode 1: step 276
# Episode 1: step 277
# Episode 1: step 278
# Episode 1: step 279
# Episode 1: step 280
#   Episode 1: ❌ 失敗  (280 steps)
# Episode 2: step 1
# Episode 2: step 2
# Episode 2: step 3
# Episode 2: step 4
# Episode 2: step 5
# Episode 2: step 6
# Episode 2: step 7
# Episode 2: step 8
# Episode 2: step 9
# Episode 2: step 10
# Episode 2: step 11
# Episode 2: step 12
# Episode 2: step 13
# Episode 2: step 14
# Episode 2: step 15
# Episode 2: step 16
# Episode 2: step 17
# Episode 2: step 18
# Episode 2: step 19
# Episode 2: step 20
# Episode 2: step 21
# Episode 2: step 22
# Episode 2: step 23
# Episode 2: step 24
# Episode 2: step 25
# Episode 2: step 26
# Episode 2: step 27
# Episode 2: step 28
# Episode 2: step 29
# Episode 2: step 30
# Episode 2: step 31
# Episode 2: step 32
# Episode 2: step 33
# Episode 2: step 34
# Episode 2: step 35
# Episode 2: step 36
# Episode 2: step 37
# Episode 2: step 38
# Episode 2: step 39
# Episode 2: step 40
# Episode 2: step 41
# Episode 2: step 42
# Episode 2: step 43
# Episode 2: step 44
# Episode 2: step 45
# Episode 2: step 46
# Episode 2: step 47
# Episode 2: step 48
# Episode 2: step 49
# Episode 2: step 50
# Episode 2: step 51
# Episode 2: step 52
# Episode 2: step 53
# Episode 2: step 54
# Episode 2: step 55
# Episode 2: step 56
# Episode 2: step 57
# Episode 2: step 58
# Episode 2: step 59
# Episode 2: step 60
# Episode 2: step 61
# Episode 2: step 62
# Episode 2: step 63
# Episode 2: step 64
# Episode 2: step 65
# Episode 2: step 66
# Episode 2: step 67
# Episode 2: step 68
# Episode 2: step 69
# Episode 2: step 70
# Episode 2: step 71
# Episode 2: step 72
# Episode 2: step 73
# Episode 2: step 74
# Episode 2: step 75
# Episode 2: step 76
# Episode 2: step 77
# Episode 2: step 78
# Episode 2: step 79
# Episode 2: step 80
# Episode 2: step 81
# Episode 2: step 82
# Episode 2: step 83
# Episode 2: step 84
# Episode 2: step 85
# Episode 2: step 86
# Episode 2: step 87
# Episode 2: step 88
# Episode 2: step 89
# Episode 2: step 90
# Episode 2: step 91
# Episode 2: step 92
# Episode 2: step 93
# Episode 2: step 94
# Episode 2: step 95
# Episode 2: step 96
# Episode 2: step 97
# Episode 2: step 98
# Episode 2: step 99
# Episode 2: step 100
# Episode 2: step 101
# Episode 2: step 102
# Episode 2: step 103
# Episode 2: step 104
# Episode 2: step 105
# Episode 2: step 106
# Episode 2: step 107
# Episode 2: step 108
# Episode 2: step 109
# Episode 2: step 110
# Episode 2: step 111
# Episode 2: step 112
# Episode 2: step 113
# Episode 2: step 114
# Episode 2: step 115
# Episode 2: step 116
# Episode 2: step 117
# Episode 2: step 118
# Episode 2: step 119
# Episode 2: step 120
# Episode 2: step 121
# Episode 2: step 122
# Episode 2: step 123
# Episode 2: step 124
# Episode 2: step 125
# Episode 2: step 126
# Episode 2: step 127
# Episode 2: step 128
# Episode 2: step 129
# Episode 2: step 130
# Episode 2: step 131
# Episode 2: step 132
# Episode 2: step 133
# Episode 2: step 134
# Episode 2: step 135
# Episode 2: step 136
# Episode 2: step 137
# Episode 2: step 138
# Episode 2: step 139
# Episode 2: step 140
# Episode 2: step 141
# Episode 2: step 142
# Episode 2: step 143
# Episode 2: step 144
# Episode 2: step 145
# Episode 2: step 146
# Episode 2: step 147
# Episode 2: step 148
# Episode 2: step 149
# Episode 2: step 150
# Episode 2: step 151
# Episode 2: step 152
# Episode 2: step 153
# Episode 2: step 154
# Episode 2: step 155
# Episode 2: step 156
# Episode 2: step 157
# Episode 2: step 158
# Episode 2: step 159
# Episode 2: step 160
# Episode 2: step 161
# Episode 2: step 162
# Episode 2: step 163
# Episode 2: step 164
# Episode 2: step 165
# Episode 2: step 166
# Episode 2: step 167
# Episode 2: step 168
# Episode 2: step 169
# Episode 2: step 170
# Episode 2: step 171
# Episode 2: step 172
# Episode 2: step 173
# Episode 2: step 174
# Episode 2: step 175
# Episode 2: step 176
# Episode 2: step 177
# Episode 2: step 178
# Episode 2: step 179
# Episode 2: step 180
# Episode 2: step 181
# Episode 2: step 182
# Episode 2: step 183
# Episode 2: step 184
# Episode 2: step 185
# Episode 2: step 186
# Episode 2: step 187
# Episode 2: step 188
# Episode 2: step 189
# Episode 2: step 190
# Episode 2: step 191
# Episode 2: step 192
# Episode 2: step 193
# Episode 2: step 194
# Episode 2: step 195
# Episode 2: step 196
# Episode 2: step 197
# Episode 2: step 198
# Episode 2: step 199
# Episode 2: step 200
# Episode 2: step 201
# Episode 2: step 202
# Episode 2: step 203
# Episode 2: step 204
# Episode 2: step 205
# Episode 2: step 206
# Episode 2: step 207
# Episode 2: step 208
# Episode 2: step 209
# Episode 2: step 210
# Episode 2: step 211
# Episode 2: step 212
# Episode 2: step 213
# Episode 2: step 214
# Episode 2: step 215
# Episode 2: step 216
# Episode 2: step 217
# Episode 2: step 218
# Episode 2: step 219
# Episode 2: step 220
# Episode 2: step 221
# Episode 2: step 222
# Episode 2: step 223
# Episode 2: step 224
# Episode 2: step 225
# Episode 2: step 226
# Episode 2: step 227
# Episode 2: step 228
# Episode 2: step 229
# Episode 2: step 230
# Episode 2: step 231
# Episode 2: step 232
# Episode 2: step 233
# Episode 2: step 234
# Episode 2: step 235
# Episode 2: step 236
# Episode 2: step 237
# Episode 2: step 238
# Episode 2: step 239
# Episode 2: step 240
# Episode 2: step 241
# Episode 2: step 242
# Episode 2: step 243
# Episode 2: step 244
# Episode 2: step 245
# Episode 2: step 246
# Episode 2: step 247
# Episode 2: step 248
# Episode 2: step 249
# Episode 2: step 250
# Episode 2: step 251
# Episode 2: step 252
# Episode 2: step 253
# Episode 2: step 254
# Episode 2: step 255
# Episode 2: step 256
# Episode 2: step 257
# Episode 2: step 258
# Episode 2: step 259
# Episode 2: step 260
# Episode 2: step 261
# Episode 2: step 262
# Episode 2: step 263
# Episode 2: step 264
# Episode 2: step 265
# Episode 2: step 266
# Episode 2: step 267
# Episode 2: step 268
# Episode 2: step 269
# Episode 2: step 270
# Episode 2: step 271
# Episode 2: step 272
# Episode 2: step 273
# Episode 2: step 274
# Episode 2: step 275
# Episode 2: step 276
# Episode 2: step 277
# Episode 2: step 278
# Episode 2: step 279
# Episode 2: step 280
#   Episode 2: ❌ 失敗  (280 steps)
#
# === 評価結果 ===
# 成功率: 33.3%  (1/3 episodes)
# 所要時間: 453.6 秒

# %%
from IPython.display import Video, display

for ep in range(N_EPISODES):
    VIDEO_PATH = f"rollout_ep{ep}.mp4"
    print(f"エピソード {ep}: {VIDEO_PATH}")
    display(Video(VIDEO_PATH, embed=True, width=480))
# Out:
# エピソード 0: rollout_ep0.mp4
# <video controls  width="480" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
# エピソード 1: rollout_ep1.mp4
# <video controls  width="480" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
# エピソード 2: rollout_ep2.mp4
# <video controls  width="480" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
